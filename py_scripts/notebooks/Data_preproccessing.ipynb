# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv("../../data/Life_Expectancy_Data.csv")
dataframe=dataframe.rename(columns={"Life expectancy ":"Life_expectancy"})

# %%
dataframe.head()
# Out:
#        Country  Year      Status  Life_expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
developed_countries = dataframe.loc[dataframe["Status"] == "Developed"].reset_index(drop = True)

developed_countries.head()
# Out:
#      Country  Year     Status  Life_expectancy  Adult Mortality  \
# 0  Australia  2015  Developed             82.8             59.0
# 1  Australia  2014  Developed             82.7              6.0
# 2  Australia  2013  Developed             82.5             61.0
# 3  Australia  2012  Developed             82.3             61.0
# 4  Australia  2011  Developed             82.0             63.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0              1      NaN                 0.00000         93.0        74  ...
# 1              1     9.71             10769.36305         91.0       340  ...
# 2              1     9.87             11734.85381         91.0       158  ...
# 3              1    10.03             11714.99858         91.0       199  ...
# 4              1    10.30             10986.26527         92.0       190  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  Population  \
# ...

# %%
developed_countries_life = developed_countries[["Country" , "Year", "Life_expectancy" ]]

developed_countries_life
# Out:
#                       Country  Year  Life_expectancy
# 0                   Australia  2015             82.8
# 1                   Australia  2014             82.7
# 2                   Australia  2013             82.5
# 3                   Australia  2012             82.3
# 4                   Australia  2011             82.0
# ..                        ...   ...              ...
# 507  United States of America  2004             77.5
# 508  United States of America  2003             77.2
# 509  United States of America  2002             77.0
# 510  United States of America  2001             76.9
# 511  United States of America  2000             76.8
#
# [512 rows x 3 columns]

# %%
developed_countries_life_15 = developed_countries_life[developed_countries_life["Year"] == 2015].reset_index(drop = True).drop("Year" , axis = 1)

developed_countries_life_15
# Out:
#                                               Country  Life_expectancy
# 0                                           Australia             82.8
# 1                                             Austria             81.5
# 2                                             Belgium             81.1
# 3                                            Bulgaria             74.5
# 4                                             Croatia             78.0
# 5                                              Cyprus             85.0
# 6                                             Czechia             78.8
# 7                                             Denmark             86.0
# 8                                             Germany             81.0
# 9                                             Hungary             75.8
# 10                                            Iceland             82.7
# 11                                            Ireland             81.4
# ...

# %%
developed_countries_life_15['Country'] = developed_countries_life_15['Country'].replace('United States of America', 'USA')
developed_countries_life_15['Country'] = developed_countries_life_15['Country'].replace('United Kingdom of Great Britain and Northern Ireland', 'England')

# %%
developed_countries_life_15.to_csv("../../data/developed/developed1-2.csv", sep=",", index = False)

# %%
developed_countries_all_aux = dataframe.loc[dataframe["Status"] == "Developed"].reset_index(drop = True)

developed_countries_all = developed_countries_all_aux.loc[developed_countries_all_aux["Year"] == 2015]

developed_countries_all
# Out:
#                                                Country  Year     Status  \
# 0                                            Australia  2015  Developed
# 16                                             Austria  2015  Developed
# 32                                             Belgium  2015  Developed
# 48                                            Bulgaria  2015  Developed
# 64                                             Croatia  2015  Developed
# 80                                              Cyprus  2015  Developed
# 96                                             Czechia  2015  Developed
# 112                                            Denmark  2015  Developed
# 128                                            Germany  2015  Developed
# 144                                            Hungary  2015  Developed
# 160                                            Iceland  2015  Developed
# 176                                            Ireland  2015  Developed
# ...

# %%
developed_countries_all.to_csv("../../data/developed/developed3.csv", sep=",", index = False)
